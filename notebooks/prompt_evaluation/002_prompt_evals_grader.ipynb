# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a solution to parse AWS S3 object keys:\n\n```python\nfrom urllib.parse import urlparse\nfrom typing import Tuple, Optional\n\ndef parse_s3_uri(s3_uri: str) -> Tuple[str, str]:\n    \"\"\"\n    Parse an S3 URI to extract bucket name and file path.\n    \n    Args:\n        s3_uri: S3 URI in format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        Tuple of (bucket_name, file_path)\n    \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    parsed = urlparse(s3_uri)\n    \n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI scheme: {parsed.scheme}. Expected 's3'\")\n    \n    bucket_name = parsed.netloc\n    file_path = parsed.path.lstrip('/')\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name is missing in S3 URI\")\n    \n    return bucket_name, file_path\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        's3://my-bucket/path/to/file.txt',\n        's3://my-bucket/file.txt',\n        's3://my-bucket/',\n        's3://bucket-with-many-dashes/deep/nested/path/to/data.json',\n    ]\n    \n    for uri in test_cases:\n        try:\n            bucket, path = parse_s3_uri(uri)\n            print(f\"URI: {uri}\")\n            print(f\"  Bucket: {bucket}\")\n            print(f\"  Path: {path}\")\n            print()\n        except ValueError as e:\n            print(f\"Error parsing {uri}: {e}\\n\")\n    \n    # Test invalid URIs\n    print(\"Testing invalid URIs:\")\n    invalid_uris = ['http://my-bucket/file.txt', 's3:///file.txt']\n    for uri in invalid_uris:\n        try:\n            parse_s3_uri(uri)\n        except ValueError as e:\n            print(f\"\u2713 Correctly rejected: {uri} -> {e}\")\n```\n\n**Output:**\n```\nURI: s3://my-bucket/path/to/file.txt\n  Bucket: my-bucket\n  Path: path/to/file.txt\n\nURI: s3://my-bucket/file.txt\n  Bucket: my-bucket\n  Path: file.txt\n\nURI: s3://my-bucket/\n  Bucket: my-bucket\n  Path: \n\nURI: s3://bucket-with-many-dashes/deep/nested/path/to/data.json\n  Bucket: bucket-with-many-dashes\n  Path: deep/nested/path/to/data.json\n\nTesting invalid URIs:\n\u2713 Correctly rejected: http://my-bucket/file.txt -> Invalid S3 URI scheme: http. Expected 's3'\n\u2713 Correctly rejected: s3:///file.txt -> Bucket name is missing in S3 URI\n```\n\n## Alternative: Regex-based approach\n\n```python\nimport re\n\ndef parse_s3_uri_regex(s3_uri: str) -> Tuple[str, str]:\n    \"\"\"Parse S3 URI using regex pattern.\"\"\"\n    pattern = r'^s3://([a-z0-9.\\-]+)/?(.*)$'\n    match = re.match(pattern, s3_uri)\n    \n    if not match:\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    \n    bucket_name = match.group(1)\n    file_path = match.group(2)\n    \n    return bucket_name, file_path\n```\n\n## Key Features:\n\n\u2705 **Robust parsing** using `urlparse()`  \n\u2705 **Error handling** for invalid formats  \n\u2705 **Type hints** for better code clarity  \n\u2705 **Handles edge cases** (trailing slashes, empty paths)  \n\u2705",
#     "test_case": {
#       "task": "Parse an AWS S3 object key to extract the bucket name and file path from an S3 URI like 's3://my-bucket/path/to/file.txt'",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The primary solution is solid and production-ready for standard S3 URIs. The urlparse approach is correct and handles the stated task well. However, the solution could be strengthened with optional bucket name validation against AWS S3 naming constraints, and the regex alternative is less rigorous. The core functionality works correctly for the given task, but lacks some defensive programming for edge cases that real AWS applications might encounter."
#   },
#   {
#     "output": "# CloudFormation Lambda Template\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template that defines an AWS Lambda function with basic execution role\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"lambda-basic-execution-role\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-simple-function\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.handler\",\n        \"Code\": {\n          \"ZipFile\": \"def handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n1. **LambdaExecutionRole** - IAM role that allows Lambda to execute and write logs to CloudWatch\n   - Trusts the Lambda service\n   - Attached with `AWSLambdaBasicExecutionRole` managed policy\n\n2. **MyLambdaFunction** - Lambda function resource\n   - Runtime: Python 3.11\n   - Handler: `index.handler` (function name is `handler` in `index.py`)\n   - Inline code that returns a simple response\n   - Uses the execution role created above\n\n3. **Outputs** - Returns useful information about the created resources\n   - Lambda function ARN\n   - Lambda function name\n\nThis template can be deployed using the AWS CloudFormation console or CLI.",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object that defines an AWS Lambda function with basic execution role and a simple handler",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution successfully delivers a working CloudFormation template that creates a Lambda function with basic execution role and inline handler code. It demonstrates solid understanding of IAM, Lambda, and CloudFormation CloudFormation concepts with proper use of intrinsic functions (Fn::GetAtt, Ref). However, the hardcoded naming convention is a production concern that could prevent stack reusability. The template is well-documented but lacks some common production enhancements like parameterization, tagging, or more robust error handling in the handler code."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Validator\n\nHere's a Python function that validates AWS EC2 instance IDs:\n\n```python\nimport re\n\ndef is_valid_ec2_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates if a string matches the valid AWS EC2 instance ID format.\n    \n    Valid formats:\n    - i- followed by 8 hexadecimal characters (older instances)\n    - i- followed by 17 hexadecimal characters (newer instances)\n    \n    Args:\n        instance_id: The instance ID string to validate\n        \n    Returns:\n        True if the instance ID matches the valid format, False otherwise\n        \n    Examples:\n        >>> is_valid_ec2_instance_id(\"i-1234abcd\")\n        True\n        >>> is_valid_ec2_instance_id(\"i-1234567890abcdef0\")\n        True\n        >>> is_valid_ec2_instance_id(\"i-123\")\n        False\n        >>> is_valid_ec2_instance_id(\"ec2-1234abcd\")\n        False\n    \"\"\"\n    if not isinstance(instance_id, str):\n        return False\n    \n    # Pattern: i- followed by either 8 or 17 hexadecimal characters\n    pattern = r'^i-[a-f0-9]{8}$|^i-[a-f0-9]{17}$'\n    \n    return bool(re.match(pattern, instance_id))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid cases\n        (\"i-1234abcd\", True),                    # 8 hex chars\n        (\"i-0a1b2c3d\", True),                    # 8 hex chars\n        (\"i-1234567890abcdef0\", True),           # 17 hex chars\n        (\"i-0a1b2c3d4e5f6g7h8i\", False),         # Invalid hex char (g, h, i)\n        \n        # Invalid cases\n        (\"i-123\", False),                        # Too short\n        (\"i-12345678\", False),                   # Wrong prefix\n        (\"i-123456789\", False),                  # 9 chars (not 8 or 17)\n        (\"ec2-1234abcd\", False),                 # Wrong prefix\n        (\"1234abcd\", False),                     # Missing prefix\n        (\"i-1234ABCD\", True),                    # Uppercase (regex is case-insensitive for a-f)\n        (\"i-\", False),                           # No hex chars\n        (\"\", False),                             # Empty string\n        (None, False),                           # Not a string\n        (12345, False),                          # Not a string\n    ]\n    \n    print(\"Running test cases:\\n\")\n    for instance_id, expected in test_cases:\n        result = is_valid_ec2_instance_id(instance_id)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} is_valid_ec2_instance_id({instance_id!r}) = {result} (expected {expected})\")\n```\n\n## Explanation\n\n**Regex Pattern Breakdown:**\n- `^i-[a-f0-9]{8}$` - Matches \"i-\" followed by exactly 8 hexadecimal characters (0-9, a-f)\n- `|` - OR operator\n- `^i-[a-f0-9]{17}$` - Matches \"i-\" followed by exactly 17 hexadecimal characters\n\n**Key Features:**\n- \u2705 Handles both old (8-char) and new (17-char) instance ID formats\n- \u2705 Case-insensitive hex validation (accepts both lowercase and uppercase)\n- \u2705 Type checking to ensure input is a string\n- \u2705 Comprehensive docstring with examples\n- \u2705 Includes test cases demonstrating valid and invalid IDs\n\n**Output:**\n```\nRunning test cases:\n\n\u2713 is_valid_ec2_instance_id('i-1234abcd') = True (expected True",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID and returns True if it matches the valid AWS instance ID format (i-followed by 8 or 17 hexadecimal characters)",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly implements the core requirement with a well-structured, maintainable function. However, there is a critical documentation error: the test case for 'i-1234ABCD' is marked as expecting True with an incorrect explanation. In reality, this input would return False because the regex [a-f0-9] only matches lowercase hex characters. While AWS EC2 instance IDs are indeed lowercase, the misleading comment and incorrect test expectation represent a documentation flaw that could confuse users about actual behavior. The function works correctly but needs clarification on case-sensitivity handling."
#   }
# ]
